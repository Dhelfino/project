# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhelfino/project/blob/main/sales_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 Analisis Penjualan E-Commerce
# Analisis data penjualan toko online untuk melihat tren produk, kategori populer, dan perilaku pelanggan.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 🔍 Produk Terlaris

# %%
top_products = sales_df.groupby('Product')['Quantity Ordered'].sum().sort_values(ascending=False)
top_products.plot(kind='bar', title='Produk Terlaris')
plt.ylabel('Jumlah Terjual')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📆 Penjualan per Bulan

# %%
sales_df['Month'] = sales_df['Order Date'].dt.to_period('M')
monthly_sales = sales_df.groupby('Month')['Quantity Ordered'].sum()
monthly_sales.plot(kind='line', marker='o', title='Penjualan per Bulan')
plt.ylabel('Jumlah Terjual')
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_matplotlib/core.py:1561: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(left, right)

# %% [markdown]
# ## 🛒 Kategori Favorit Pelanggan

# %%
category_sales = sales_df.groupby('Category')['Quantity Ordered'].sum().sort_values(ascending=False)
category_sales.plot(kind='bar', color='skyblue', title='Kategori Favorit')
plt.ylabel('Jumlah Terjual')
plt.tight_layout()
plt.show()
